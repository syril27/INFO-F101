# %% [markdown]
# <a href="https://colab.research.google.com/github/syril27/INFO-F101/blob/main/Cours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<u>**Programmation : Cours**</u>

# %% [markdown]
# ---

# %% [markdown]
# ##<u> **Cours 1** <u/> (16/09)

# %% [markdown]
# # Introduction
#
# ## Types de langages
#
# * **Interprété** : le code est traduit et exécuté en même temps.
#   *Exemple : Python*
#
# * **Compilé** : le code est d’abord entièrement traduit (compilé) en langage machine, puis exécuté.
#   *Exemple : C, C++*
#
#
#
# ## Fonction `print()` en Python
#
# * Sert à afficher du texte ou des valeurs à l’écran.
# * Syntaxe :
#
#   ```python
#   print("Bonjour")
#   print("La somme est :", 2 + 3)
#   ```

# %% [markdown]
# ---

# %% [markdown]
# ##<u> **Cours 2** <u/> (22/09)

# %% [markdown]
# # Bases
#
# ## Types
#
# * `int` : entier
# * `float` : nombres à virgule flottante
# * `str` : chaînes de caractères
#
#
# ## Opérateurs
#
# * Addition : `+`
# * Soustraction : `-`
# * Multiplication : `*`
# * Division : `/`
# * Division entière : `//`
# * Modulo : `%`
# * Exposant : `**`
#
# ### Priorité des opérateurs (du plus fort au plus faible)
#
# 1. Parenthèses : `()`
# 2. Exposant : `**`
# 3. Signes : `+x`, `-x`
# 4. Multiplication et divisions : `*`, `/`, `//`, `%`
# 5. Addition et soustraction : `+`, `-`
#
#
#
# ## Chaînes de caractères
#
# * Concaténation avec `+`
#
#   ```python
#   "bonjour" + " tout le monde"  # "bonjour tout le monde"
#   ```
# * Répétition avec `*` (uniquement avec un entier)
#
#   ```python
#   "ha" * 3  # "hahaha"
#   ```
#
#
#
# ## Variables
#
# * Une variable est un **nom qui référence une valeur stockée en mémoire**.
# * Sert à mémoriser des données pour les réutiliser.
#
# Exemple :
#
# ```python
# x = 3
# mon_message = "bonjour"
# ```
#
# ### Règles de nommage
#
# * Utiliser des noms explicites, en minuscules, avec `_` :
#
#   ```python
#   ma_variable = 10
#   ```
#
# ### Manipulation
#
# ```python
# a = 5
# b = a
# a = 6
# # b vaut toujours 5
# ```
#
#
#
# ## Commentaires
#
# * Ligne :
#
#   ```python
#   # Ceci est un commentaire
#   ```
# * Bloc :
#
#   ```python
#   """
#   Ceci est
#   un commentaire
#   sur plusieurs lignes
#   """
#   ```
#
#
#
# ## Conversion de types
#
# * `int(x)` : convertit en entier
# * `float(x)` : convertit en flottant
# * `str(x)` : convertit en chaîne
#
#
# ## Input
#
# ```python
# nom = input("Entrez votre nom : ")
# age = int(input("Entrez votre âge : "))
# ```
#
# * `input()` lit toujours une chaîne → conversion nécessaire si numérique.
#
#
#
# ## Module `math`
#
# ```python
# import math
#
# math.sqrt(x)       # racine carrée
# math.pow(x, y)     # puissance
# math.exp(x)        # exponentielle
# math.log(x)        # logarithme népérien
# math.log(x, base)  # log dans une base donnée
# math.sin(x), math.cos(x), math.tan(x)
# math.pi, math.e
# ```
#
#
#
# ## Module `turtle`
#
# Permet de dessiner avec une tortue graphique.
#
# ```python
# import turtle
#
# turtle.forward(100)   # avance
# turtle.right(90)      # tourne à droite
# turtle.color("blue")  # change couleur
# turtle.circle(50)     # dessine cercle
# turtle.done()         # garde la fenêtre ouverte
# ```
#
#
# ## Caractères d’échappement
#
# * `\n` : saut de ligne
# * `\t` : tabulation
# * `\"` : guillemets doubles
# * `\\` : antislash
#
# Exemple :
#
# ```python
# print("Bonjour\nComment ça va ?")
# print("Il a dit : \"Salut !\"")
# ```
#
#
# ## Assignation multiple
#
# ```python
# x, y = 3, 7
# print(x)  # 3
# print(y)  # 7
#
# # Échange de variables
# a, b = b, a
# ```
#
# ---

# %% [markdown]
# ##<u> **Cours 3** <u/> (30/09)

# %% [markdown]
# # Instructions conditionnelles et boucles
#
# ## Conditions
#
# * `if / elif / else` : exécuté seulement si la condition est vraie
#
# ### Syntaxe complète
#
# ```python
# if condition:
#     instructions
# elif condition:
#     instructions
# elif condition:
#     instructions
# else:
#     instructions
# ```
#
# ### Indentation
#
# * Convention : **4 espaces**
#
# ## Type booléen
#
# * Deux valeurs possibles : `True`, `False`
#
# Exemples :
#
# ```python
# a = 3 < 5      # True
# b = (10 == 2)  # False
# ```
#
# ## Opérateurs relationnels
#
# * `==` : égal à
# * `!=` : différent de
# * `<`, `<=` : inférieur (ou égal)
# * `>`, `>=` : supérieur (ou égal)
#
# ## Opérateurs logiques
#
# * `and` : conjonction → `True` si les deux sont `True`
# * `or` : disjonction → `True` si au moins un est `True`
# * `not` : négation → inverse le résultat
#
# Exemple :
#
# ```python
# x = 5
# print(x > 0 and x < 10)   # True
# print(not(x < 0))         # True
# ```
#
# ## Logique booléenne
#
# * Conjonction : ∧
# * Disjonction : ∨
# * Négation : ¬
#
# ### Lois de De Morgan
#
# * ¬(A ∧ B) ⇔ (¬A) ∨ (¬B)
# * ¬(A ∨ B) ⇔ (¬A) ∧ (¬B)
#
# En Python :
#
# ```python
# not (A and B)  ⇔  (not A) or (not B)
# not (A or B)   ⇔  (not A) and (not B)
# ```
#
# ## Boucle `while`
#
# * Répète un bloc tant que la condition est vraie
#
# ### Syntaxe
#
# ```python
# while condition:
#     instructions
# ```
#
# ### Exemple
#
# ```python
# i = 0
# while i < 5:
#     print(i)
#     i += 1
# ```
#
# ## Boucle `for`
#
# * La fonction `range(n)` génère une séquence de `0` à `n-1`.
#
# ### Syntaxe
#
# ```python
# for x in sequence:
#     instructions
# ```
#
# * La variable `x` prend les valeurs successives de la séquence.
#
# ---

# %% [markdown]
# ##<u> **Cours 4** <u/> (7/10)

# %% [markdown]
# # Fonctions en Python
#
# ## Fonctions prédéfinies
#
# * `abs()` : renvoie la valeur absolue d’un nombre.
# * `float()` : convertit une valeur en **nombre à virgule flottante**.
# * `max()` : renvoie le **maximum** des valeurs en entrée.
# * `math.sin()` et `math.cos()` : fonctions **trigonométriques**, disponibles dans le module `math`.
# * `math.log()` : renvoie le **logarithme** du nombre en entrée.
#
#
#
# ## Définir une fonction
#
# * Une **fonction** encapsule un **bloc de code réutilisable**.
#
# ### Syntaxe
#
# ```python
# def nom_fonction(paramètres):
#     instructions
# ```
#
# ### Exemple
#
# ```python
# def saluer(nom):
#     print(f"Bonjour, {nom} !")
# ```
#
#
#
# ## Séquence d’exécution
#
# * Le programme s’exécute **ligne par ligne**.
# * Une fonction est **définie une seule fois**, mais **appelée plusieurs fois**.
#
#
#
# ## Paramètres
#
# * Les paramètres sont placés entre parenthèses, séparés par des virgules.
# * L’appel doit **respecter l’ordre** et le **nombre** des paramètres.
# * Lors de l’exécution, les **paramètres formels** deviennent des **variables locales**.
#
#
#
# ## Instruction `return`
#
# * `return` permet de **renvoyer un résultat** à l’appelant.
# * Dès qu’elle est exécutée, la fonction se termine.
# * Sans `return`, la fonction renvoie **`None`**.
#
# ### Exemple
#
# ```python
# def carre(n):
#     return n * n
#
# res = carre(5)
# print(res)  # 25
# ```
#
#
#
# ## Confusion entre `print` et `return`
#
# | Fonction  | Effet                              | Valeur renvoyée     |
# | --------- | ---------------------------------- | ------------------- |
# | `print()` | Affiche une valeur dans la console | `None`              |
# | `return`  | Renvoie une valeur à l’appelant    | Valeur réutilisable |
#
#
# ## Fonctions booléennes
#
# Une fonction peut **retourner un booléen** (`True` ou `False`), utile dans les conditions.
#
# ### Exemple
#
# ```python
# def est_pair(n):
#     return n % 2 == 0
#
# print(est_pair(6))  # True
# print(est_pair(7))  # False
# ```
#
#
#
# ## Fonctions sans paramètres
#
# Une fonction peut être définie **sans paramètre** si elle n’a besoin d’aucune information externe.
#
# ### Exemple
#
# ```python
# def afficher_titre():
#     print("=== MON PROGRAMME ===")
#
# afficher_titre()
# ```
#
#
#
# ## Annotation de type
#
# L’**annotation de type** (ou *type hinting*) indique les types des arguments et du retour d’une fonction.
#
# ### Exemple
#
# ```python
# def aire_rectangle(longueur: float, largeur: float) -> float:
#     return longueur * largeur
# ```
#
#
#
# ## Variables locales et globales
#
# * **Variable locale** : définie **dans une fonction**, n’existe que **pendant son exécution**.
# * **Variable globale** : définie **en dehors d’une fonction**, accessible partout (sauf si masquée par une locale).
#
# ### Exemple
#
# ```python
# x = 10  # globale
#
# def f():
#     x = 5  # locale
#     print(x)  # 5
#
# f()
# print(x)  # 10
# ```
#
#
#
# ## Portée et visibilité des variables (LEGB)
#
# Python suit le modèle **LEGB** :
#
# | Niveau            | Description                                |
# | ----------------- | ------------------------------------------ |
# | **L (Local)**     | Variable définie dans la fonction en cours |
# | **E (Enclosing)** | Variable d’une fonction englobante         |
# | **G (Global)**    | Variable du module courant                 |
# | **B (Built-in)**  | Fonctions et constantes intégrées à Python |
#
# ---

# %% [markdown]
# ##<u> **Cours 5** <u/> (14/10)

# %% [markdown]
# # Séquences en Python
#
# ## Chaînes de caractères (`str`)
#
# * Une **chaîne** (string) est une **séquence de caractères**.
# * Type Python : `str`.
# * Les **chaînes sont immuables** → on ne peut pas les modifier.
# * Indexation, **tranches** (slicing) et **méthodes intégrées** disponibles.
#
# ### Exemple
#
# ```python
# s = "Python"
# print(s[0])      # 'P'
# print(s[1:4])    # 'yth'
# print(len(s))    # 6
# print(s.upper()) # 'PYTHON'
# ```
#
#
#
# ## Indices
#
# * On accède aux éléments d’une séquence avec `sequence[index]`.
# * Les indices vont de **0 à n−1**, où `n` est la longueur de la séquence.
# * Les **indices négatifs** existent :
#
#   * `-1` → dernier élément
#   * `-2` → avant-dernier, etc.
#
#
# ## Tuples et listes
#
# * **Liste (`list`)** : séquence **muable**, entre crochets `[ ]`.
# * **Tuple (`tuple`)** : séquence **immuable**, entre parenthèses `( )`.
#
# ### Exemple
#
# ```python
# L = [1, 2, 3]
# print(type(L))       # <class 'list'>
# L.append(4)          # [1, 2, 3, 4]
# L[0] = -1            # [-1, 2, 3, 4]
#
# T = (10, 20, 30)
# print(type(T))       # <class 'tuple'>
# # T[0] = 100 → Erreur : tuple immuable
#
# print(len(T))        # 3
# print(L[1])          # 2
# ```
#
#  **Tuples** pour données fixes, **listes** pour données dynamiques.
#
#
#
# ## Opérateur `in`
#
# Deux usages principaux :
#
# 1. **Itération** dans une boucle
# 2. **Test d’appartenance**
#
# ### Exemple
#
# ```python
# # 1. Boucle
# for lettre in "Python":
#     print(lettre)
#
# # 2. Test d’appartenance
# voyelles = ['a', 'e', 'i', 'o', 'u', 'y']
# print('e' in voyelles)  # True
# print('z' in voyelles)  # False
# ```
#
#
#
# ## Slicing (Tranches)
#
# Permet d’extraire une **sous-partie** d’une séquence.
#
# ### Syntaxe
#
# ```python
# sequence[start:stop:step]
# ```
#
# ### Exemple
#
# ```python
# s = [0, 1, 2, 3, 4, 5]
# print(s[1:4])   # [1, 2, 3]
# print(s[:3])    # [0, 1, 2]
# print(s[::2])   # [0, 2, 4]
# print(s[::-1])  # [5, 4, 3, 2, 1, 0]
# ```
#
# * La **borne supérieure n’est pas incluse**.
# * Fonctionne avec les **listes**, **tuples** et **chaînes**.
# * Les tranches créent **de nouvelles séquences**.
#
#
#
# ## Listes et assignations
#
# Lorsqu’on écrit :
#
# ```python
# A = [1, 2, 3, 4]
# B = A
# B[0] = -1
# print(A)  # [-1, 2, 3, 4]
# ```
#
#  `A` et `B` pointent vers **le même objet en mémoire**.
# La variable ne copie pas la liste, elle **copie la référence (pointeur)**.
#
#
#
# ## Identité et égalité
#
# | Opérateur | Teste...                            | Exemple  | Résultat          |
# | --------- | ----------------------------------- | -------- | ----------------- |
# | `==`      | L’**égalité de contenu**            | `a == b` | `True`            |
# | `is`      | L’**identité mémoire** (même objet) | `a is b` | `False` (souvent) |
#
# ```python
# a = [1, 2, 3]
# b = [1, 2, 3]
# c = a
#
# print(a == b)  # True  → même contenu
# print(a is b)  # False → objets distincts
# print(a is c)  # True  → même objet
# ```
#
#
#
# ## Paramètres de fonctions : muables ou immuables
#
# * Les **objets muables** (ex : listes) peuvent être **modifiés** dans une fonction.
# * Les **objets immuables** (ex : entiers, tuples, chaînes) **ne le peuvent pas**.
#
# ### Exemple
#
# ```python
# def modifie(liste):
#     liste.append(4)
#
# a = [1, 2, 3]
# modifie(a)
# print(a)  # [1, 2, 3, 4]
#
#
# def modifie_str(s):
#     s = s + "!"
#
# b = "bonjour"
# modifie_str(b)
# print(b)  # "bonjour"
# ```
#
#  Les objets **muables** sont **passés par référence**.
#
#
#
# ## Séquences de séquences
#
# Les **listes** et **tuples** peuvent contenir **des éléments de types variés**, y compris d’autres listes ou tuples.
#
# ### Exemple
#
# ```python
# L = ['bonjour', 14, 3.14, True]
# T = ('bonjour', 14, 3.14, True)
#
# L2 = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# L3 = [(1, 2), (3, 4), (5, 6)]
#
# print(type(L3))        # <class 'list'>
# print(type(L3[0]))     # <class 'tuple'>
# print(type(L3[0][0]))  # <class 'int'>
# ```
#
#
#
# ## Méthodes sur les chaînes (`str`)
#
# | Méthode           | Description                                     |
# | ----------------- | ----------------------------------------------- |
# | `s.lower()`       | Met la chaîne en minuscules                     |
# | `s.upper()`       | Met la chaîne en majuscules                     |
# | `s.strip()`       | Supprime les espaces autour                     |
# | `s.replace(a, b)` | Remplace `a` par `b`                            |
# | `s.find(x)`       | Donne l’indice de la première occurrence de `x` |
# | `s.split(sep)`    | Découpe la chaîne selon `sep`                   |
# | `s.join(L)`       | Concatène les éléments de `L`, séparés par `s`  |
# | `s.startswith(x)` | Teste si la chaîne commence par `x`             |
# | `s.endswith(x)`   | Teste si la chaîne se termine par `x`           |
#
# Toutes ces méthodes retournent une **nouvelle chaîne** (les chaînes sont **immuables**).
#
# ---
#
# ## Méthodes sur les listes (`list`)
#
# | Méthode          | Description                                                     |
# | ---------------- | --------------------------------------------------------------- |
# | `l.append(x)`    | Ajoute `x` à la fin                                             |
# | `l.insert(i, x)` | Insère `x` à l’indice `i`                                       |
# | `l.remove(x)`    | Supprime la **première occurrence** de `x`                      |
# | `l.pop([i])`     | Retire et renvoie l’élément à l’indice `i` (dernier par défaut) |
# | `l.index(x)`     | Renvoie l’indice de la première occurrence de `x`               |
# | `l.count(x)`     | Renvoie le **nombre d’occurrences** de `x`                      |
# | `l.sort()`       | Trie la liste en place                                          |
# | `l.reverse()`    | Inverse les éléments                                            |
# | `l.copy()`       | Crée une **copie superficielle**                                |
# | `l.clear()`      | Supprime tous les éléments                                      |
#
# ---
#
# ## Compréhensions de liste
#
# Permettent de créer des listes **en une seule ligne**.
#
# ### Syntaxe
#
# ```python
# [expression for variable in iterable if condition]
# ```
#
# ### Exemples
#
# ```python
# # Carrés de 0 à 9
# carres = [x**2 for x in range(10)]
#
# # Nombres pairs de 0 à 19
# pairs = [x for x in range(20) if x % 2 == 0]
# ```

# %% [markdown]
# ---

# %% [markdown]
# ##<u> **Cours 6** <u/> (21/10)

# %% [markdown]
# # Fichiers et Matrices en Python
#
#
#
# ## Fichiers
#
# ### Écrire dans un fichier
#
# La fonction `open()` permet d’**ouvrir un fichier** avec un **nom** et un **mode** :
#
# | Mode  | Signification                         |
# | ----- | ------------------------------------- |
# | `"w"` | écriture (écrase le contenu existant) |
# | `"r"` | lecture                               |
# | `"a"` | ajout à la fin du fichier             |
#
# ### Exemple
#
# ```python
# f = open("notes.txt", "w")
# f.write("Bonjour\n")
# f.write("Ligne suivante\n")
# f.close()
# ```
#
#  La méthode `close()` **ferme le fichier** et termine les opérations d’écriture.
#
# ### Encodage
#
# On peut préciser l’encodage (souvent `utf-8`) :
#
# ```python
# f = open("res.txt", "w", encoding="utf-8")
# ```
#
#
#
# ## Lire un fichier ligne par ligne
#
# Les méthodes **`read()`**, **`readline()`** et **`readlines()`** permettent de lire le contenu.
#
# ### Exemple avec `for` sur le fichier
#
# ```python
# f = open("notes.txt", "r")
# for ligne in f:
#     print(ligne.strip())
# f.close()
# ```
#
# ### Exemple avec `readlines()`
#
# ```python
# f = open("notes.txt", "r")
# lignes = f.readlines()
# for l in lignes:
#     print(l.upper())
# f.close()
# ```
#
# Chaque ligne lue contient un **symbole de fin de ligne** `\n` à la fin.
#
#
#
# ## `with ... as`
#
# La structure `with ... as` permet une **gestion automatique** de l’ouverture et de la fermeture du fichier (pas besoin de `close()`).
#
# ### Exemple
#
# ```python
# with open("notes.txt", "r") as f:
#     for ligne in f:
#         print(ligne.strip())
# ```
#
#  Le fichier est **fermé automatiquement** à la fin du bloc.
#
#
#
# # Matrices
#
# ## Représenter une matrice
#
# Une **matrice** peut être représentée par une **liste de listes** :
#
# ```python
# matrice = [
#     [1, 2, 3],
#     [4, 5, 6],
#     [7, 8, 9]
# ]
# ```
#
# ### Accès à un élément
#
# On utilise **deux indices** :
#
# ```python
# matrice[1][2]  # 6
# ```
#
# ### Parcours complet de la matrice
#
# ```python
# for ligne in matrice:
#     for val in ligne:
#         print(val)
# ```
#
# ---

# %% [markdown]
# ##<u> **Cours 7** <u/> (3/11)

# %% [markdown]
# # Ensembles et Dictionnaires en Python
#
#
# ## Ensembles (`set`)
#
# * Le type `set` définit une **structure de données non ordonnée** contenant des **éléments uniques** (pas de doublons).
#
# * Les ensembles sont **muables**.
#
# ### Principales opérations
#
# | Méthode / Opération | Description                        |
# | ------------------- | ---------------------------------- |
# | `add(x)`            | Ajoute un élément                  |
# | `remove(x)`         | Supprime un élément                |
# | `len(s)`            | Nombre d’éléments                  |
# | `set()`             | Conversion (ex : liste → ensemble) |
# | `clear()`           | Vide l’ensemble                    |
# | `x in s`            | Teste l’appartenance               |
#
# ### Exemple
#
# ```python
# fruits = {"pomme", "banane", "orange"}
# fruits.add("kiwi")
# fruits.remove("orange")
# print(len(fruits))  # 3
# print("pomme" in fruits)  # True
# ```
#
#
# ## Opérations ensemblistes
#
# Les ensembles supportent les **opérations mathématiques classiques** :
#
# ```python
# A = {1, 2, 3}
# B = {3, 4, 5}
#
# print(A | B)  # Union → {1, 2, 3, 4, 5}
# print(A & B)  # Intersection → {3}
# print(A - B)  # Différence → {1, 2}
# ```
#
# ## Dictionnaires (`dict`)
#
# * Un **dictionnaire** associe des **clés** à des **valeurs**.
# * Chaque clé est **unique**.
# * Délimité par des **accolades `{ }`**.
#
# ### Exemple
#
# ```python
# personne = {
#     "nom": "Alice",
#     "age": 30,
#     "ville": "Paris"
# }
#
# print(personne["nom"])  # Alice
# ```
#
# ### Ajout ou modification
#
# ```python
# personne["age"] = 31
# personne["email"] = "alice@mail.com"
# ```
#
#
# ## Méthodes et parcours de dictionnaire
#
# | Méthode         | Description                       |
# | --------------- | --------------------------------- |
# | `dict.keys()`   | Retourne toutes les clés          |
# | `dict.values()` | Retourne toutes les valeurs       |
# | `dict.items()`  | Retourne les paires (clé, valeur) |
#
# ### Exemple de parcours
#
# ```python
# for cle, valeur in personne.items():
#     print(cle, ":", valeur)
# ```
#
# ### Test d’appartenance
#
# ```python
# if "nom" in personne:
#     print("Nom trouvé")
# ```
#
#
# ## Types et restrictions
#
# * Les **ensembles (`set`)** et **dictionnaires (`dict`)** sont **muables et hétérogènes**.
#
# *  Les **clés** d’un dictionnaire doivent être **immuables** :
#
#   * `int`, `float`, `str`, ou `tuple`.
#
# ### Exemple
#
# ```python
# ang2fr = {'one': 'un', 'two': 'deux', 'three': 'trois'}
#
# d = {
#     'ent': 1,
#     'list': [1, 2, 3],
#     (1, 2): 3.14,
#     'dic': ang2fr
# }
# ```
#
#
# ## Itérations et modifications
#
# On **ne peut pas** ajouter ou supprimer des éléments d’un ensemble **pendant une itération** :
#
# ```python
# s = {'a', 'b', 'c', 'd', 'e'}
# for i in s:
#     if i in 'aeiouy':
#         s.remove(i)  # Erreur d’exécution
# ```
#
#
# ## Lettres communes entre deux mots
#
# On peut trouver les **lettres communes** à deux mots en utilisant les ensembles :
#
# ```python
# list(set("pommeee") & set("banane"))  # ['e']
# ```
#
# ### Sous forme de fonction
#
# ```python
# def lettres_communes(mot1, mot2):
#     return list(set(mot1) & set(mot2))
# ```
#
#
# ## Fonction `histogramme()`
#
# Renvoie un **dictionnaire** des lettres d’une chaîne avec leur **fréquence d’apparition**.
#
# ### Exemple
#
# ```python
# def histogramme(s):
#     """Renvoie le dictionnaire des lettres dans s avec leur fréquence."""
#     d = {}  # dictionnaire vide
#     for c in s:
#         if c not in d:
#             d[c] = 1
#         else:
#             d[c] += 1
#     return d
# print(histogramme("bonjour"))
# # {'b': 1, 'o': 2, 'n': 1, 'j': 1, 'u': 1, 'r': 1}
# ```
#
# ---

# %% [markdown]
# ##<u> **Cours 8** <u/> (4/11)

# %% [markdown]
# # Récursivité en Python
#
#
#
# ## Qu’est-ce que la récursivité ?
#
# * La **récursivité** est une **technique de programmation** où **une fonction s’appelle elle-même**.
#
# * Elle est utilisée pour résoudre un problème en le divisant en **sous-problèmes similaires**.
#
# ### Une fonction récursive comporte :
#
# * Un ou plusieurs **cas de base** (ou conditions d’arrêt).
# * Un ou plusieurs **appels récursifs**.
#
# ##  Multiplication par addition (récursive)
#
# $$
# a \times b = a + a \times (b - 1)
# $$
#
#
# ```python
# def multiplication_recursive(a, b):
#     if b == 0:
#         return 0
#     else:
#         return a + multiplication_recursive(a, b - 1)
# ```
#
#
# ## Définition récursive de la factorielle
#
# $$
# n! =
# \begin{cases}
# 1 & \text{si } n = 0 \\
# n \times (n-1)! & \text{si } n > 0
# \end{cases}
# $$
#
#
#
# ### Implémentation :
#
# ```python
# def factorielle(n):
#     if n == 0:
#         return 1
#     else:
#         return n * factorielle(n - 1)
# ```
#
# **Remarques :**
#
# * Chaque appel crée un **nouveau contexte** (valeur propre de `n`).
#
# * Les appels sont **empilés**, puis **dépilés** à la fin.
#
# * La taille de la pile dépend de `n`.
#
#
#
# ##  Appel récursif unique
#
# Un **appel récursif unique** signifie qu’il n’y a **qu’un seul appel** à la fonction dans son corps.
#
# ```python
# def rec(n):
#     if n > 0:
#         print('a')
#         rec(n - 1)
#         print('b')
# ```
#
# → La fonction s’appelle **une seule fois par exécution**.
#
#
#
# ##  Récursivité terminale
#
# Une **récursion terminale** a lieu lorsque **l’appel récursif est la dernière instruction** de la fonction.
# Cela permet une **meilleure gestion de la pile** (optimisation possible).
#
# ```python
# def fact(n, acc=1):
#     if n == 0:
#         return acc
#     return fact(n - 1, acc * n)  # appel récursif terminal
# ```
#
#
# ##  Récursivité et induction
#
# La **récursivité** en programmation est proche de **l’induction mathématique** :
#
# | Étape | Récursivité    | Induction                  |
# | ----- | -------------- | -------------------------- |
# | 1     | Cas de base    | Initialisation             |
# | 2     | Appel récursif | Passage à l’étape suivante |
#
#  En induction, on prouve une propriété pour `n = 0`, puis on montre que **si elle est vraie pour n, elle l’est aussi pour n + 1**.
#
#
# ##  Reconnaître un palindrome
#
# Un **palindrome** est un mot qui se lit **de la même manière dans les deux sens**.
#
# ### Méthode récursive :
#
# 1. Cas de base : chaîne vide ou à un seul caractère → palindrome.
# 2. Si les extrémités sont égales → vérifier le mot sans les extrêmes.
# 3. Sinon → ce n’est pas un palindrome.
#
# ```python
# def est_palindrome(s):
#     if len(s) <= 1:
#         return True
#     if s[0] != s[-1]:
#         return False
#     return est_palindrome(s[1:-1])
# ```
#
# Exemples :
#
# ```python
# est_palindrome("radar")  # True
# est_palindrome("python") # False
# ```
#
#
#
# ##  Tours de Hanoï
#
# ### Règles :
#
# * Un seul disque déplacé à la fois.
# * Aucun disque plus grand ne peut être posé sur un plus petit.
#
# ### Principe récursif :
#
# 1. **Cas de base** : 1 disque → déplacement direct.
# 2. **Sinon** :
#
#    * Déplacer `n-1` disques du piquet source vers l’auxiliaire.
#    * Déplacer le disque `n` vers la cible.
#    * Déplacer les `n-1` disques de l’auxiliaire vers la cible.
#
# ### Code :
#
# ```python
# def hanoi(n, source, cible, auxiliaire):
#     if n == 1:
#         print(f"Déplacer disque 1 de {source} à {cible}")
#     else:
#         hanoi(n - 1, source, auxiliaire, cible)
#         print(f"Déplacer disque {n} de {source} à {cible}")
#         hanoi(n - 1, auxiliaire, cible, source)
#
# hanoi(3, 'A', 'B', 'C')
# ```
#
#
#
# ## ⚡ Tri rapide (Quicksort)
#
# ### Principe :
#
# 1. Choisir un **pivot** (ex : premier élément).
# 2. Diviser la liste en :
#
#    * `left` : éléments ≤ pivot
#    * `right` : éléments > pivot
# 3. Trier récursivement `left` et `right`.
#
# ### Code Python :
#
# ```python
# def quicksort(lst):
#     if len(lst) <= 1:
#         return lst
#     pivot = lst[0]
#     left = [x for x in lst[1:] if x <= pivot]
#     right = [x for x in lst[1:] if x > pivot]
#     return quicksort(left) + [pivot] + quicksort(right)
# ```
#
# Exemple :
#
# ```python
# print(quicksort([4, 2, 7, 1, 3]))
# # [1, 2, 3, 4, 7]
# ```
# ---
